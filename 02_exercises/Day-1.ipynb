# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5

# %% [markdown]
# Types: int, float
# Resolves to: int

# %%
9 / 2

# %% [markdown]
# Types: int
# Resolves to: float

# %%
1.5 * 2 >= 7 - 3

# %% [markdown]
# Types: float, int
# Resolves to: bool

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4

# %% [markdown]
# (6 * 3) and (7 * 4) to 18 + 28 -> 46

# %%
5 - 2 * 3 ** 4

# %% [markdown]
# (3 ** 4) to 81 -> (2 * 81) to 162 -> 5 - 162 = -157

# %%
(5 - 2) * 3 ** 4

# %% [markdown]
# (5 - 2) to 3 -> (3 ** 4) to 81 -> 3 * 81 to 243

# %%
5 + 2 >= 3 * 4

# %% [markdown]
# (3 * 4) to 12 -> (5 + 2) to 7; 7 >= 12 -> False

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# *Your answer here*

# %%
84 *= 0.5 / 7

# %% [markdown]
# Incorrect operator

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# *Your answer here*

# %%
5 * 3 = weight

# %% [markdown]
# Variable definition cannot start with an integer.

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# *Your answer here*

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

# Your code goes here

value == str
if value == str:
    print("Valid")
else:
    raise Exception("Must be a string")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_2611/918421668.py in <cell line: 0>()
#       7     print("Valid")
#       8 else:
# ----> 9     raise Exception("Must be a string")
#
# Exception: Must be a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])

# %% [markdown]
# The correct print function would be: print(arr[2])

# %%
fullName = "Taylor Swift"
print(full_name)

# %% [markdown]
# The variable is stored poorly. For correct output the print function should read: print(FullName)

# %%
2 + '2' + 4

# %% [markdown]
# '2' is not defined as a string.

# %% [markdown]
# ## Functions

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
def convert_to_miles(kilometers: int):
  """convert kilometers to miles
  Parameters: kilometers (int)
  Returns: miles (float)
  """
  miles = kilometers / 1.6
  return miles

# %%
convert_to_miles(10)
# Out:
# 6.25

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# Out:
# 3

# %% [markdown]
# 3

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    #
    >>> repeat('yesnomaybe', 3)
    # yesnomaybeyesnomaybeyesnomaybe
    '''
    output = string * num

    return output

# %%
repeat('yay',9)
# Out:
# 'yayyayyayyayyayyayyayyayyay'

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    if number[:3] == '(416)':
        return True
    else:
        return False
